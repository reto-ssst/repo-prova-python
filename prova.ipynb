# %% [markdown]
# # Jupyter Notebook
#
# Questo è un notebook jupyter.
# Ogni cella può essere eseguita singolarmente.

# %%
print('Questo è un file python')
# Out:
# Questo è un file python

# %%
a=6
b=3

# %%
print('a =',a)
print('b =',b)
print('a+b =',a+b)
# Out:
# a = 6
# b = 3
# a+b = 9

# %% [markdown]
# $ \sin(x) $
